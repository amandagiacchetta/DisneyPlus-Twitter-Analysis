# %%
import pandas as pd
import numpy as np 
import glob

# %%
path = r'C:\Users\amand\Documents\Jupyter Notebooks\DisneyPlus\data_final_pkl' # use your path
all_files = glob.glob(path + "\*.pkl")

all_

for file in all_files:

# %%
frame = pd.concat(tweets)

# %%
df = pd.read_pickle(r'C:\\Users\\amand\\Documents\\Jupyter Notebooks\\DisneyPlus\\data_final_pkl\\until_04_11.pkl', compression='infer')

# %%
df
# Out:
#     user_screen_name              user_id  user_is_verified  \
# 0      Jose_Navas_Jr             32901996             False
# 1    zucatellidanilo           2978733862             False
# 2     WilliamsHenriq           1462821571             False
# 3        Karolmebaby  1025340762303750144             False
# 4           ally_blu            225906556             False
# ..               ...                  ...               ...
# 868     diangelobiaa   752130915220877312             False
# 869          selgzth  1154415416938311680             False
# 870   julioaugustofs  1246626154666172416             False
# 871         kamersaa  1078038632391458816             False
# 872     TiniPrincxsa           2842192979             False
#
#     retweeted_from_screen_name    retweeted_from_id  \
# 0                      vcfaztv             16354038
# 1                    globoplay             55569724
# 2                    globoplay             55569724
# ...

# %%
all_files
# Out:
# ['C:\\Users\\amand\\Documents\\Jupyter Notebooks\\DisneyPlus\\data_final_pkl\\until_04_11.pkl',
#  'C:\\Users\\amand\\Documents\\Jupyter Notebooks\\DisneyPlus\\data_final_pkl\\until_05_11.pkl',
#  'C:\\Users\\amand\\Documents\\Jupyter Notebooks\\DisneyPlus\\data_final_pkl\\until_06_11.pkl',
#  'C:\\Users\\amand\\Documents\\Jupyter Notebooks\\DisneyPlus\\data_final_pkl\\until_08_11.pkl',
#  'C:\\Users\\amand\\Documents\\Jupyter Notebooks\\DisneyPlus\\data_final_pkl\\until_10_11.pkl',
#  'C:\\Users\\amand\\Documents\\Jupyter Notebooks\\DisneyPlus\\data_final_pkl\\until_12_11.pkl',
#  'C:\\Users\\amand\\Documents\\Jupyter Notebooks\\DisneyPlus\\data_final_pkl\\until_13_11.pkl']

# %%
C:\Users\amand\Documents\Jupyter Notebooks\DisneyPlus\data_final_pkl\until_04_11.pkl
