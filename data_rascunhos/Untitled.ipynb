# %%
import pandas as pd

# %%
df = pd.read_csv('teste1000.csv')

# %%
df
# Out:
#      Unnamed: 0 extended_entities place  in_reply_to_status_id_str  favorited  \
# 0             0               NaN   NaN                        NaN      False
# 1             1               NaN   NaN                        NaN      False
# 2             2               NaN   NaN                        NaN      False
# 3             3               NaN   NaN                        NaN      False
# 4             4               NaN   NaN                        NaN      False
# ..          ...               ...   ...                        ...        ...
# 995         995               NaN   NaN                        NaN      False
# 996         996               NaN   NaN                        NaN      False
# 997         997               NaN   NaN                        NaN      False
# 998         998               NaN   NaN                        NaN      False
# 999         999               NaN   NaN                        NaN      False
#
# ...
